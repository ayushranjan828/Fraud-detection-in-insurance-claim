# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Data.csv')
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# 0       466132  ...         2                     YES              71610
# 1       468176  ...         0                       ?               5070
# 2       430632  ...         3                      NO              34650
# 3       608117  ...         2                      NO              63400
# 4       610706  ...         1                      NO               6500
#
#   injury_claim property_claim  vehicle_claim  auto_make auto_model auto_year  \
# 0         6510          13020          52080       Saab        92x      2004
# 1          780            780           3510   Mercedes       E400      2007
# 2         7700           3850          23100      Dodge        RAM      2007
# 3         6340           6340          50720  Chevrolet      Tahoe      2014
# 4         1300            650           4550     Accura        RSX      2009
#
#   fraud_reported
# 0              Y
# 1              Y
# 2              N
# 3              Y
# 4              N
#
# [5 rows x 39 columns]

# %%
data.replace('?', np.nan, inplace=True)
data.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# min               433.330000   -1.000000e+06  430104.000000       0.000000
# 25%              1089.607500    0.000000e+00  448404.500000       0.000000
# 50%              1257.200000    0.000000e+00  466445.500000       0.000000
# 75%              1415.695000    0.000000e+00  603251.000000   51025.000000
# max              2047.590000    1.000000e+07  620962.000000  100500.000000
#
#         capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# count    1000.000000               1000.000000                   1000.00000
# mean   -26793.700000                 11.644000                      1.83900
# std     28104.096686                  6.951373                      1.01888
# min   -111100.000000                  0.000000                      1.00000
# 25%    -51500.000000                  6.000000                      1.00000
# 50%    -23250.000000                 12.000000                      1.00000
# 75%         0.000000                 17.000000                      3.00000
# max         0.000000                 23.000000                      4.00000
#
#        bodily_injuries    witnesses  total_claim_amount  injury_claim  \
# count      1000.000000  1000.000000          1000.00000   1000.000000
# mean          0.992000     1.487000         52761.94000   7433.420000
# std           0.820127     1.111335         26401.53319   4880.951853
# min           0.000000     0.000000           100.00000      0.000000
# 25%           0.000000     1.000000         41812.50000   4295.000000
# 50%           1.000000     1.000000         58055.00000   6775.000000
# 75%           2.000000     2.000000         70592.50000  11305.000000
# max           2.000000     3.000000        114920.00000  21450.000000
#
#        property_claim  vehicle_claim    auto_year
# count     1000.000000    1000.000000  1000.000000
# mean      7399.570000   37928.950000  2005.103000
# std       4824.726179   18886.252893     6.015861
# min          0.000000      70.000000  1995.000000
# 25%       4445.000000   30292.500000  2000.000000
# 50%       6750.000000   42100.000000  2005.000000
# 75%      10885.000000   50822.500000  2010.000000
# max      23670.000000   79560.000000  2015.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               822 non-null    object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        909 non-null    object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              640 non-null    object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      657 non-null    object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
# dtypes: float64(1), int64(17), object(21)
# memory usage: 304.8+ KB

# %%
data.isna().sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted           91
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                360
# bodily_injuries                  0
# witnesses                        0
# police_report_available        343
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# auto_make                        0
# auto_model                       0
# auto_year                        0
# fraud_reported                   0
# dtype: int64

# %%
missing = data.isnull().sum() / len(data)
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing = missing.to_frame()
missing.columns = ['Null_Count']
missing.index.names = ['Column_Name']
missing = missing.reset_index()

sns.set(style = 'whitegrid', color_codes = True)
plt.figure(figsize=(10, 6))
sns.barplot(x = 'Column_Name', y = 'Null_Count', data = missing)

plt.xticks(rotation = 30)
plt.show()

# %%
data['collision_type'] = data['collision_type'].fillna(data['collision_type'].mode()[0])
data['property_damage'] = data['property_damage'].fillna(data['property_damage'].mode()[0])
data['police_report_available'] = data['police_report_available'].fillna(data['police_report_available'].mode()[0])

# %%
plt.figure(figsize=(18,15))

numeric_data = data.select_dtypes(include='number')
corr = numeric_data.corr()
sns.heatmap(data = corr, annot = True, fmt = '.1g', linewidths = 2)
plt.show()

# %%
unique = data.nunique().to_frame()
unique.columns = ['Count']
unique.index.names = ['ColName']
unique = unique.reset_index()
sns.set(style='whitegrid', color_codes=True)
sns.barplot(x='ColName', y='Count',data = unique)
plt.xticks(rotation = 90)
plt.show()

# %%
unique.sort_values(by='Count', ascending=False)
# Out:
#                         ColName  Count
# 2                 policy_number   1000
# 24            incident_location   1000
# 9                   insured_zip    995
# 7         policy_annual_premium    991
# 3              policy_bind_date    951
# 31           total_claim_amount    763
# 34                vehicle_claim    726
# 32                 injury_claim    638
# 33               property_claim    626
# 0            months_as_customer    391
# 16                 capital-loss    354
# 15                capital-gains    338
# 17                incident_date     60
# 1                           age     46
# 36                   auto_model     39
# 25     incident_hour_of_the_day     24
# 37                    auto_year     21
# 13              insured_hobbies     20
# 12           insured_occupation     14
# 35                    auto_make     14
# 8                umbrella_limit     11
# 11      insured_education_level      7
# 22               incident_state      7
# 23                incident_city      7
# 14         insured_relationship      6
# 26  number_of_vehicles_involved      4
# 21        authorities_contacted      4
# 20            incident_severity      4
# 18                incident_type      4
# 29                    witnesses      4
# 19               collision_type      3
# 28              bodily_injuries      3
# 6             policy_deductable      3
# 5                    policy_csl      3
# 4                  policy_state      3
# 30      police_report_available      2
# 27              property_damage      2
# 10                  insured_sex      2
# 38               fraud_reported      2

# %%
data.head()
# Out:
# ColName  months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                       328   48         521585       10/17/2014           OH
# 1                       228   42         342868        6/27/2006           IN
# 2                       134   29         687698         9/6/2000           OH
# 3                       256   41         227811        5/25/1990           IL
# 4                       228   44         367455         6/6/2014           IL
#
# ColName policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0          250/500               1000                1406.91               0
# 1          250/500               2000                1197.22         5000000
# 2          100/300               2000                1413.14         5000000
# 3          250/500               2000                1415.74         6000000
# 4         500/1000               1000                1583.91         6000000
#
# ColName  insured_zip  ... witnesses police_report_available  \
# 0             466132  ...         2                     YES
# 1             468176  ...         0                      NO
# 2             430632  ...         3                      NO
# 3             608117  ...         2                      NO
# 4             610706  ...         1                      NO
#
# ColName total_claim_amount injury_claim property_claim  vehicle_claim  \
# 0                    71610         6510          13020          52080
# 1                     5070          780            780           3510
# 2                    34650         7700           3850          23100
# 3                    63400         6340           6340          50720
# 4                     6500         1300            650           4550
#
# ColName  auto_make auto_model auto_year fraud_reported
# 0             Saab        92x      2004              Y
# 1         Mercedes       E400      2007              Y
# 2            Dodge        RAM      2007              N
# 3        Chevrolet      Tahoe      2014              Y
# 4           Accura        RSX      2009              N
#
# [5 rows x 39 columns]

# %%
plt.figure(figsize=(18, 15))


numeric_data = data.select_dtypes(include='number')
corr = numeric_data.corr()


mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(data=corr, mask=mask, annot=True, fmt='.2g', linewidths=1)
plt.show()

# %%
numeric_data = data.select_dtypes(include='number')
corr = numeric_data.corr()

plt.figure(figsize=(18, 15))
mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(data=corr, mask=mask, annot=True, fmt='.2g', linewidths=1)
plt.show()

# %%
data.drop(columns=['age', 'total_claim_amount'], inplace=True, axis=1)
data.head()
# Out:
# ColName  months_as_customer  policy_number policy_bind_date policy_state  \
# 0                       328         521585       10/17/2014           OH
# 1                       228         342868        6/27/2006           IN
# 2                       134         687698         9/6/2000           OH
# 3                       256         227811        5/25/1990           IL
# 4                       228         367455         6/6/2014           IL
#
# ColName policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0          250/500               1000                1406.91               0
# 1          250/500               2000                1197.22         5000000
# 2          100/300               2000                1413.14         5000000
# 3          250/500               2000                1415.74         6000000
# 4         500/1000               1000                1583.91         6000000
#
# ColName  insured_zip insured_sex  ... bodily_injuries witnesses  \
# 0             466132        MALE  ...               1         2
# 1             468176        MALE  ...               0         0
# 2             430632      FEMALE  ...               2         3
# 3             608117      FEMALE  ...               1         2
# 4             610706        MALE  ...               0         1
#
# ColName police_report_available injury_claim  property_claim  vehicle_claim  \
# 0                           YES         6510           13020          52080
# 1                            NO          780             780           3510
# 2                            NO         7700            3850          23100
# 3                            NO         6340            6340          50720
# 4                            NO         1300             650           4550
#
# ColName  auto_make auto_model auto_year fraud_reported
# 0             Saab        92x      2004              Y
# 1         Mercedes       E400      2007              Y
# 2            Dodge        RAM      2007              N
# 3        Chevrolet      Tahoe      2014              Y
# 4           Accura        RSX      2009              N
#
# [5 rows x 37 columns]

# %%
x = data.drop('fraud_reported', axis=1)
y = data['fraud_reported']

categorical_cols = x.select_dtypes(include=['object'])
categorical_cols = pd.get_dummies(categorical_cols, drop_first=True)
categorical_cols.head()
# Out:
#    policy_bind_date_1/1/2008  policy_bind_date_1/10/2004  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
#
#    policy_bind_date_1/10/2012  policy_bind_date_1/11/2009  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    policy_bind_date_1/11/2010  policy_bind_date_1/12/2010  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    policy_bind_date_1/12/2012  policy_bind_date_1/13/1991  \
# 0                       False                       False
# 1                       False                       False
# 2                       False                       False
# 3                       False                       False
# 4                       False                       False
#
#    policy_bind_date_1/14/1998  policy_bind_date_1/14/1999  ...  \
# 0                       False                       False  ...
# 1                       False                       False  ...
# 2                       False                       False  ...
# 3                       False                       False  ...
# 4                       False                       False  ...
#
#    auto_model_Pathfinder  auto_model_RAM  auto_model_RSX  \
# 0                  False           False           False
# 1                  False           False           False
# 2                  False            True           False
# 3                  False           False           False
# 4                  False           False            True
#
#    auto_model_Silverado  auto_model_TL  auto_model_Tahoe  auto_model_Ultima  \
# 0                 False          False             False              False
# 1                 False          False             False              False
# 2                 False          False             False              False
# 3                 False          False              True              False
# 4                 False          False             False              False
#
#    auto_model_Wrangler  auto_model_X5  auto_model_X6
# 0                False          False          False
# 1                False          False          False
# 2                False          False          False
# 3                False          False          False
# 4                False          False          False
#
# [5 rows x 2132 columns]

# %%
numeric_cols = x.select_dtypes(include=['int64'])
x = pd.concat([numeric_cols, categorical_cols], axis=1)
x.head()
# Out:
#    months_as_customer  policy_number  policy_deductable  umbrella_limit  \
# 0                 328         521585               1000               0
# 1                 228         342868               2000         5000000
# 2                 134         687698               2000         5000000
# 3                 256         227811               2000         6000000
# 4                 228         367455               1000         6000000
#
#    insured_zip  capital-gains  capital-loss  incident_hour_of_the_day  \
# 0       466132          53300             0                         5
# 1       468176              0             0                         8
# 2       430632          35100             0                         7
# 3       608117          48900        -62400                         5
# 4       610706          66000        -46000                        20
#
#    number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# 0                            1                1  ...                  False
# 1                            1                0  ...                  False
# 2                            3                2  ...                  False
# 3                            1                1  ...                  False
# 4                            1                0  ...                  False
#
#    auto_model_RAM  auto_model_RSX  auto_model_Silverado  auto_model_TL  \
# 0           False           False                 False          False
# 1           False           False                 False          False
# 2            True           False                 False          False
# 3           False           False                 False          False
# 4           False            True                 False          False
#
#    auto_model_Tahoe  auto_model_Ultima  auto_model_Wrangler  auto_model_X5  \
# 0             False              False                False          False
# 1             False              False                False          False
# 2             False              False                False          False
# 3              True              False                False          False
# 4             False              False                False          False
#
#    auto_model_X6
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 2147 columns]

# %%
plt.figure(figsize=(20,15))
plotnumber = 1

for col in x.columns:
    if plotnumber <= 24:
        ax = plt.subplot(5, 5, plotnumber)
        sns.boxplot(x[col])
        plt.xlabel(col, fontsize = 15)
    plotnumber += 1
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25)
x_train.head()
# Out:
#      months_as_customer  policy_number  policy_deductable  umbrella_limit  \
# 817                 250         254837                500               0
# 937                 458         535879               1000               0
# 349                 230         331595               1000         7000000
# 312                 158         278091               2000               0
# 688                 290         885789               1000               0
#
#      insured_zip  capital-gains  capital-loss  incident_hour_of_the_day  \
# 817       457962          69500        -40700                        16
# 937       472236          31400             0                        23
# 349       454530          68600        -22300                         0
# 312       440930              0        -38600                         0
# 688       472922              0        -61400                        20
#
#      number_of_vehicles_involved  bodily_injuries  ...  auto_model_Pathfinder  \
# 817                            1                1  ...                  False
# 937                            1                2  ...                  False
# 349                            1                1  ...                  False
# 312                            1                0  ...                  False
# 688                            3                1  ...                  False
#
#      auto_model_RAM  auto_model_RSX  auto_model_Silverado  auto_model_TL  \
# 817           False           False                 False          False
# 937           False           False                 False          False
# 349           False           False                 False           True
# 312           False           False                 False          False
# 688           False           False                 False          False
#
#      auto_model_Tahoe  auto_model_Ultima  auto_model_Wrangler  auto_model_X5  \
# 817             False              False                False          False
# 937             False              False                False          False
# 349             False              False                False          False
# 312             False              False                False          False
# 688             False              False                False          False
#
#      auto_model_X6
# 817          False
# 937          False
# 349          False
# 312          False
# 688          False
#
# [5 rows x 2147 columns]

# %%
numerical_data = x_train[['months_as_customer', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss',  'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'injury_claim', 'property_claim', 'vehicle_claim']]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_data)

scaled_num_df = pd.DataFrame(data = scaled_data, columns=numerical_data.columns, index=x_train.index)
scaled_num_df.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 817            0.402582          -1.037671       -0.478431       1.583278
# 937            2.213245          -0.226991       -0.478431       0.226264
# 349            0.228480          -0.226991        2.562443       1.551222
# 312           -0.398288           1.394371       -0.478431      -0.892115
# 688            0.750787          -0.226991       -0.478431      -0.892115
#
#      capital-loss  number_of_vehicles_involved  bodily_injuries  witnesses  \
# 817     -0.467199                    -0.823439         0.021212  -0.444356
# 937      0.974438                    -0.823439         1.245010   0.458807
# 349      0.184548                    -0.823439         0.021212   1.361970
# 312     -0.392815                    -0.823439        -1.202585  -1.347519
# 688     -1.200415                     1.130926         0.021212   1.361970
#
#      injury_claim  property_claim  vehicle_claim
# 817      1.236744       -0.135080       0.873481
# 937      1.390919        1.441277       0.270184
# 349      1.488292        1.541364       0.346929
# 312     -0.812157       -0.093378      -0.720033
# 688     -0.256317        1.049273      -0.030399

# %%
x_train.drop(columns = scaled_num_df.columns, inplace = True)

# %%
x_train = pd.concat([scaled_num_df, x_train], axis = 1)

# %%
x_train.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 817            0.402582          -1.037671       -0.478431       1.583278
# 937            2.213245          -0.226991       -0.478431       0.226264
# 349            0.228480          -0.226991        2.562443       1.551222
# 312           -0.398288           1.394371       -0.478431      -0.892115
# 688            0.750787          -0.226991       -0.478431      -0.892115
#
#      capital-loss  number_of_vehicles_involved  bodily_injuries  witnesses  \
# 817     -0.467199                    -0.823439         0.021212  -0.444356
# 937      0.974438                    -0.823439         1.245010   0.458807
# 349      0.184548                    -0.823439         0.021212   1.361970
# 312     -0.392815                    -0.823439        -1.202585  -1.347519
# 688     -1.200415                     1.130926         0.021212   1.361970
#
#      injury_claim  property_claim  ...  auto_model_Pathfinder  auto_model_RAM  \
# 817      1.236744       -0.135080  ...                  False           False
# 937      1.390919        1.441277  ...                  False           False
# 349      1.488292        1.541364  ...                  False           False
# 312     -0.812157       -0.093378  ...                  False           False
# 688     -0.256317        1.049273  ...                  False           False
#
#      auto_model_RSX  auto_model_Silverado  auto_model_TL  auto_model_Tahoe  \
# 817           False                 False          False             False
# 937           False                 False          False             False
# 349           False                 False           True             False
# 312           False                 False          False             False
# 688           False                 False          False             False
#
#      auto_model_Ultima  auto_model_Wrangler  auto_model_X5  auto_model_X6
# 817              False                False          False          False
# 937              False                False          False          False
# 349              False                False          False          False
# 312              False                False          False          False
# 688              False                False          False          False
#
# [5 rows x 2147 columns]

# %%
from sklearn.svm import SVC

svc_model = SVC()

svc_model.fit(x_train, y_train)
y_pred = svc_model.predict(x_train)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

svc_model_train_acc = accuracy_score(y_train, svc_model.predict(x_train))
print("Training accuracy:", svc_model_train_acc)
# Out:
# Training accuracy: 0.748

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

knn_model = KNeighborsClassifier(n_neighbors=30)

knn_model.fit(x_train, y_train)

x_test_reordered = x_test[x_train.columns]

y_pred = knn_model.predict(x_test_reordered)

knn_model_train_acc = accuracy_score(y_train, knn_model.predict(x_train))
knn_model_test_acc = accuracy_score(y_test, y_pred)


print("Training Accuracy:", knn_model_train_acc)
print("Testing Accuracy:", knn_model_test_acc)


print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))


print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Training Accuracy: 0.748
# Testing Accuracy: 0.768
# Confusion Matrix:
# [[192   0]
#  [ 58   0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.77      1.00      0.87       192
#            Y       0.00      0.00      0.00        58
#
#     accuracy                           0.77       250
#    macro avg       0.38      0.50      0.43       250
# weighted avg       0.59      0.77      0.67       250

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(x_train, y_train)


y_pred_test = decision_tree_model.predict(x_train)


decision_tree_model_train_acc = accuracy_score(y_train, decision_tree_model.predict(x_train))
decision_tree_model_test_acc = accuracy_score(y_train, y_pred_test)

print("Training accuracy: ", decision_tree_model_train_acc)
print("Test accuracy: ", decision_tree_model_test_acc)


print(confusion_matrix(y_train, y_pred_test))
print(classification_report(y_train, y_pred_test))
# Out:
# Training accuracy:  1.0
# Test accuracy:  1.0
# [[561   0]
#  [  0 189]]
#               precision    recall  f1-score   support
#
#            N       1.00      1.00      1.00       561
#            Y       1.00      1.00      1.00       189
#
#     accuracy                           1.00       750
#    macro avg       1.00      1.00      1.00       750
# weighted avg       1.00      1.00      1.00       750

# %%
from sklearn.model_selection import GridSearchCV

grid_params = {
        'criterion' : ['gini', 'entropy'],
        'max_depth' : [3, 5, 7, 10],
        'min_samples_split' : range(2, 10, 1),
        'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(decision_tree_model, grid_params, cv=5, n_jobs=-1, verbose=1)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 7, 'min_samples_leaf': 8, 'min_samples_split': 2}
# 0.852

# %%
decision_tree_model = grid_search.best_estimator_
x_test = x_test[x_train.columns]   #new line
y_pred = decision_tree_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

decision_tree_model_train_acc = accuracy_score(y_train, decision_tree_model.predict(x_train))
decision_tree_model_test_acc = accuracy_score(y_test, y_pred)

print("Training accuracy: ", decision_tree_model_train_acc)
print("Test accuracy: ", decision_tree_model_test_acc)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy:  0.8826666666666667
# Test accuracy:  0.764
# [[151  41]
#  [ 18  40]]
#               precision    recall  f1-score   support
#
#            N       0.89      0.79      0.84       192
#            Y       0.49      0.69      0.58        58
#
#     accuracy                           0.76       250
#    macro avg       0.69      0.74      0.71       250
# weighted avg       0.80      0.76      0.78       250

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier (criterion= 'entropy', max_depth= 15, max_features= 'sqrt', min_samples_leaf = 1, min_samples_split = 3, n_estimators= 14)
rf_model.fit(x_train, y_train)
y_pred = rf_model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


rf_model_train_acc = accuracy_score(y_train, rf_model.predict(x_train))


rf_model_test_acc = accuracy_score(y_test, y_pred)

print("Training accuracy:", rf_model_train_acc)
print("Test accuracy:", rf_model_test_acc)


print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))


print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy: 0.804
# Test accuracy: 0.764
# Confusion Matrix:
# [[190   2]
#  [ 57   1]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.77      0.99      0.87       192
#            Y       0.33      0.02      0.03        58
#
#     accuracy                           0.76       250
#    macro avg       0.55      0.50      0.45       250
# weighted avg       0.67      0.76      0.67       250

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


gb = GradientBoostingClassifier()
gb.fit(x_train, y_train)


y_pred_test = gb.predict(x_train)


gb_acc = accuracy_score(y_train, y_pred_test)


print(f"Training Accuracy of Gradient Boosting Classifier: {accuracy_score(y_train, gb.predict(x_train))}")
print(f"Test Accuracy of Gradient Boosting Classifier: {gb_acc} \n")


print("Confusion Matrix:")
print(confusion_matrix(y_train, y_pred_test))


print("Classification Report:")
print(classification_report(y_train, y_pred_test))
# Out:
# Training Accuracy of Gradient Boosting Classifier: 0.972
# Test Accuracy of Gradient Boosting Classifier: 0.972
#
# Confusion Matrix:
# [[552   9]
#  [ 12 177]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.98      0.98      0.98       561
#            Y       0.95      0.94      0.94       189
#
#     accuracy                           0.97       750
#    macro avg       0.97      0.96      0.96       750
# weighted avg       0.97      0.97      0.97       750

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


sgb = GradientBoostingClassifier(subsample=0.90, max_features=0.70)
sgb.fit(x_train, y_train)


sgb_pred = sgb.predict(x_train)


sgb_acc = accuracy_score(y_train, sgb_pred)


print(f"Training Accuracy of Stochastic Gradient Boosting: {accuracy_score(y_train, sgb.predict(x_train))}")
print(f"Test Accuracy of Stochastic Gradient Boosting: {sgb_acc} \n")


print("Confusion Matrix:")
print(confusion_matrix(y_train, sgb_pred))


print("Classification Report:")
print(classification_report(y_train, sgb_pred))
# Out:
# Training Accuracy of Stochastic Gradient Boosting: 0.9666666666666667
# Test Accuracy of Stochastic Gradient Boosting: 0.9666666666666667
#
# Confusion Matrix:
# [[554   7]
#  [ 18 171]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.97      0.99      0.98       561
#            Y       0.96      0.90      0.93       189
#
#     accuracy                           0.97       750
#    macro avg       0.96      0.95      0.95       750
# weighted avg       0.97      0.97      0.97       750

# %%
from sklearn.ensemble import VotingClassifier


classifiers = [('Support Vector Classifier', svc_model), 
               ('knn_model', knn_model), 
               ('Decision Tree', decision_tree_model), 
               ('Gradient Boosting Classifier', gb), 
               ('SGB', sgb),
]


vc = VotingClassifier(estimators=classifiers)


vc.fit(x_train, y_train)


y_pred = vc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


vc_train_acc = accuracy_score(y_train, vc.predict(x_train))


vc_test_acc = accuracy_score(y_test, y_pred)


print(f"Training accuracy of Voting Classifier is: {vc_train_acc}")
print(f"Test accuracy of Voting Classifier is: {vc_test_acc}")


print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))


print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Voting Classifier is: 0.928
# Test accuracy of Voting Classifier is: 0.824
# Confusion Matrix:
# [[174  18]
#  [ 26  32]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            N       0.87      0.91      0.89       192
#            Y       0.64      0.55      0.59        58
#
#     accuracy                           0.82       250
#    macro avg       0.76      0.73      0.74       250
# weighted avg       0.82      0.82      0.82       250

# %%
import pandas as pd


model_names = ['knn_model', 'Decision Tree', 'Random Forest', 'Gradient Boost', 'SGB']
test_accuracies = [knn_model_test_acc, decision_tree_model_test_acc, rf_model_test_acc, gb_acc, sgb_acc]


models_df = pd.DataFrame({'Model': model_names, 'Score': test_accuracies})


models_sorted = models_df.sort_values(by='Score', ascending=False)


print(models_sorted)
# Out:
#             Model     Score
# 3  Gradient Boost  0.972000
# 4             SGB  0.966667
# 0       knn_model  0.768000
# 1   Decision Tree  0.764000
# 2   Random Forest  0.764000

# %%
import matplotlib.pyplot as plt

plt.bar(models_df['Model'], models_sorted['Score'], width=0.4, color='maroon')
plt.xlabel("Models")
plt.xticks(rotation=90)
plt.ylabel("Scores")
plt.title("Models for Insurance Fraud Detection")
plt.show()
